# %%
import numpy as np
import math
import qiskit
from math import sqrt

from qiskit import QuantumCircuit
from qiskit import execute, Aer, BasicAer
from qiskit.tools.visualization import circuit_drawer
from qiskit.tools.visualization import plot_histogram
from qiskit.tools.visualization import plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit import transpile
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_21564\2678631983.py:7: DeprecationWarning: BasicAer is deprecated since Qiskit 0.46 and will be removed in Qiskit 1.0. The BasicAer (qiskit.providers.basicaer) module has been superseded by  qiskit.providers.basic_provider, and all its classes have been renamed to follow a new naming convention. More information and migration guidelines can be found in the 0.46 API docs for BasicAer.
#   from qiskit import execute, Aer, BasicAer

# %% [markdown]
# Soal matematis nomer 5

# %%
qc = QuantumCircuit(3)        # Buat sirkuit kuantum dengan 4 qubit: q2, q1, q0
qc.h(0)
qc.h(2)
qc.barrier()
qc.y(0)
qc.z(1)
qc.x(2)
qc.barrier()
qc.cx(0,1)
qc.y(2)
qc.barrier()
qc.z(1)
qc.swap(0,2)
qc.barrier()

qc.ccx(2,1,0)


qc.draw('mpl')
# Out:
# c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Keadaan Akhir dari qc
psi_1=Statevector(qc)
psi_1.draw('latex')
# Out:
# $$- \frac{1}{2} |000\rangle+\frac{1}{2} |001\rangle+\frac{1}{2} |110\rangle- \frac{1}{2} |111\rangle$$

# %% [markdown]
# Soal Program 1.a

# %%
qc1 = QuantumCircuit(3)
qc1.h([0,1,2])
qc1.barrier()
qc1.x(0)
qc1.cx(1,2)
qc1.y(2)
qc1.barrier()
qc1.ccx(0,1,2)
qc1.x(0)
qc1.y(1)
qc1.barrier()
qc1.z(1)
qc1.swap(0,2)
qc1.barrier()

qc1.draw('mpl')
# Out:
# c:\Users\danie\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# Soal program 1.b

# %%
qc2 =QuantumCircuit(3)
qc2.h([0,2])
qc2.x(1)
qc2.barrier()
qc2.cx(0,1)
qc2.z([0,2])
qc2.barrier()
qc2.z([0,2])
qc2.cx(0,1)
qc2.barrier()
qc2.h([0,2])
qc2.x(1)
qc2.draw('mpl')

# %% [markdown]
# Soal program 1.c

# %%
qc3 = QuantumCircuit(3)
qc3.h([0,1,2])
qc3.barrier()
qc3.x(1)
qc3.h(2)
qc3.ccx(0,1,2)
qc3.x(1)
qc3.h(2)
qc3.barrier()
qc3.draw('mpl')

# %% [markdown]
# Soal 2.a

# %%
psi=Statevector(qc1)
psi.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{4} |000\rangle- \frac{\sqrt{2}}{4} |001\rangle- \frac{\sqrt{2}}{4} |010\rangle+\frac{\sqrt{2}}{4} |011\rangle- \frac{\sqrt{2}}{4} |100\rangle+\frac{\sqrt{2}}{4} |101\rangle- \frac{\sqrt{2}}{4} |110\rangle+\frac{\sqrt{2}}{4} |111\rangle$$

# %% [markdown]
# Soal 2.b

# %%
psi=Statevector(qc2)
psi.draw('latex')
# Out:
# $$ |000\rangle$$

# %% [markdown]
# Soal 2.c

# %%
psi=Statevector(qc3)
psi.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{4} |000\rangle+\frac{\sqrt{2}}{4} |001\rangle+\frac{\sqrt{2}}{4} |010\rangle+\frac{\sqrt{2}}{4} |011\rangle+\frac{\sqrt{2}}{4} |100\rangle- \frac{\sqrt{2}}{4} |101\rangle+\frac{\sqrt{2}}{4} |110\rangle+\frac{\sqrt{2}}{4} |111\rangle$$
